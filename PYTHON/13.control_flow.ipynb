# %% [markdown]
# ## Control Flow

# %%
# break
# continue
# else
# pass

# %%
# break

numeros = [1,2,3,4,5,6,7]

for numero in numeros:
    print(numero)
    
    if numero == 3:
        break
    
    
alumnos = ["Jorge", "Sara", "Manuel", "Carlos", "Gabriel"]

for nombre in alumnos:
    print(f'Revisando:', nombre)
    
    if(nombre == "Sara"):
        print(f"{nombre} encontrado")
        break
# Out:
# 1
# 2
# 3
# Revisando: Jorge
# Revisando: Sara
# Sara encontrado

# %%
# continue

numeros = [1,2,3,4,5,6,7]

for numero in numeros:
    if numero == 3:
        continue
    
    print(numero)
    
    
alumnos = ["Jorge", "Sara", "Manuel", "Byron", "Carlos", "Gabriel"]

for nombre in alumnos:
    if(nombre == "Byron"):
        continue
    
    print(f"Alumno normal:", nombre)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7
# Alumno normal: Jorge
# Alumno normal: Sara
# Alumno normal: Manuel
# Alumno normal: Carlos
# Alumno normal: Gabriel

# %%
numeros = [1,2,3,4,5]

for numero in numeros:
    print(numero)
else:
    print("El bucle ha terminado")
# Out:
# 1
# 2
# 3
# 4
# 5
# El bucle ha terminado

# %%
for numero in range(5):
    pass

if(True):
    pass

alumnos = ["Jorge", "Sara", "Manuel", "Byron", "Carlos", "Gabriel"]

for nombre in alumnos:
   if nombre == "Byron":
       pass
   else:
       print(nombre)
# Out:
# Jorge
# Sara
# Manuel
# Carlos
# Gabriel

# %%
contador = 0

while contador <=5:
    print(contador)
    
    if(contador == 3):
        break
    contador += 1
# Out:
# 0
# 1
# 2
# 3
